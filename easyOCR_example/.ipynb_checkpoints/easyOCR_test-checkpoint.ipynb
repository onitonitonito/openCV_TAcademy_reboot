# %%
"""
# Colab example - news daum : https://bit.ly/2QtrcrD
"""
# TODO: NOT FINISHED YET!

print(__doc__)
# Out:
# # Colab example - news daum : https://bit.ly/2QtrcrD

# %%
import PIL
import easyocr
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import ImageDraw
from _path import DIR_HOME, get_cut_dir, stop_if_none

dir_ocr = DIR_HOME + 'src\\easyOCR\\'
dir_result = DIR_HOME + 'src\\resultOCR\\'

# %%
# filename = 'korean.png'                 #  5 recogs
# filename = 'namecard_extracted.png'     #  7 recogs
# filename = 'english.png'                # 11 recogs
# filename = 'news_daum.png'              # 41 recogs
filename = 'AI_compete_2020_KOGAS.jpg'  # 72 recogs

size_targeted = (640, 400)              # resize scale
post_fix = filename.split('.')[0].split('_')[0]

# %%
# TO LOAD IMAGE
im = PIL.Image.open(dir_ocr + filename)
im = stop_if_none(im, message='Image loading failed!')

im_resize = im.resize(size_targeted, PIL.Image.ANTIALIAS)
im_resize = stop_if_none(im_resize, message='Image loading failed!')

# TO SHOW IMAGES : ORIGINAL vs. RESIZE
# im_resize.show()
# im.show()             # NO need ... im_boxed image shows

reader = easyocr.Reader(['en', 'ko',])
bounds = reader.readtext(dir_ocr + filename)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
# Draw bounding boxes
def draw_boxes(image, bounds, color='yellow', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

# %%
# %matplotlib inline
im_boxed = draw_boxes(im, bounds)
# im_boxed.show()

# 저장할 파일 Type : JPEG, PNG 등
# 저장할 때 Quality 수준 : 보통 95 사용
im_boxed.save(dir_result + f"im_boxed_{post_fix}.png", "png", quality=95 )

im_boxed
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2481x3508 at 0x22F85D97B00>

# %%
probs, recogs = [], []

for idx, line in enumerate(bounds):
    recognition = line[-2]
    probablity = line[-1] * 100

    recogs.append([idx, recognition])
    probs.append([idx, probablity])

    print(f"{probablity:0.2f} % ... | {recognition:30}")
# Out:
# 33.72 % ... | 합쿡기[스공시
# 49.18 % ... | 제2회한국가스공사 (KOGAS)
# 2.60 % ... | 빅데0I터l:인곰지|늠
# 26.96 % ... | 스타트업겸진대회
# 91.00 % ... | 8.25
# 97.04 % ... | 7.17
# 57.27 % ... | 으
# 71.81 % ... | 참가신첨
# 7.89 % ... | 자세한 내용은 www kogasbigstar.com 공지사항을 통해 확인 부탁드립니다.
# 17.81 % ... | 3|9
# 58.61 % ... | 톨
# 81.67 % ... | UNG
# 92.92 % ... | 대회목적
# 98.60 % ... | 상금
# 5.59 % ... | 4t산업 추진관련기술력있는 스타트업의발굴및육성
# 99.72 % ... | 4등
# 99.46 % ... | 특별상
# 99.62 % ... | 1등
# 98.96 % ... | 2등
# 99.37 % ... | 3등
# 91.68 % ... | 5등
# 0.28 % ... | 우수 스타트업과T역기업1칭을 통한 혁신 클리스E 조성
# 63.80 % ... | 1,000만원
# 48.99 % ... | 1,0O0만원
# 87.17 % ... | 1,500만원
# 20.83 % ... | TD0만원
# 73.68 % ... | 500만원
# 38.63 % ... | 300관원
# 28.68 % ... | (1O0만원x10팀)
# 98.85 % ... | 주제
# 17.15 % ... | 후속지원계획(우수 스타트업 대상)
# 13.18 % ... | 한국가스공사의 운영데이터를 활용하여 설비효율성및안전성 등을
# 14.13 % ... | 제그할수있= 알그리즘개발
# 8.02 % ... | 실데0E를 활용한 후속과제 수행및현장 검증지원
# 0.04 % ... | ㆍ공식 홈IOT너에설명호 자르 참그
# 2.41 % ... | 지역기업과괘징을 통한시스템 적용및사업화T원
# 77.44 % ... | 참가대상
# 98.91 % ... | 추진일정
# 1.92 % ... | 빅데OE으공7능스타트업및계비창업가
# 17.44 % ... | (창업7년 DI내기업
# 6.23 % ... | 2013.07.01 0|후사업7-등록 업체)
# 77.72 % ... | 참가접수
# 45.94 % ... | 2020.07.17.(금) ~2020.08.25.(화)
# 74.59 % ... | 참가 접수
# 99.33 % ... | 설명회
# 99.61 % ... | 서류심사
# 73.05 % ... | 온라인 예선
# 17.94 % ... | 본선및 시상
# 97.34 % ... | 07.17
# 97.79 % ... | 08.25
# 97.23 % ... | 08.28
# 96.86 % ... | 09.03
# 95.06 % ... | 11.20
# 92.65 % ... | 12.10
# 94.59 % ... | 07.29
# 62.38 % ... | ~
# 82.43 % ... | 참가신청방법
# 17.53 % ... | 잠가신청/,가발계획/,동의서,기타 증빙/류
# 2.39 % ... | 이메일 kogasbigstarOnaver com)제출
# 1.21 % ... | 상세 주진일정은 주초측으사정에파라 변경될 수있습_다.
# 53.36 % ... | KQRAA
# 98.83 % ... | 지능정보산업협회
# 30.15 % ... | xtdata 한국데이터산업진흥원
# 82.96 % ... | 한국정보화진흥원
# 10.40 % ... | 합쿡기스공시
# 83.69 % ... | NIA
# 45.10 % ... | K츨DIA/사|한국데이터산업협회
# 94.27 % ... | 주최/주관
# 98.87 % ... | 후원
# 14.99 % ... | AIA
# 0.55 % ... | Intelliqence Industny Association
# 0.07 % ... | 4+++751-
# 62.16 % ... | 사단법민 한국민곰지눔협회

# %%
# TO ANALYZE STATICS of PROBABLITY
df_probs = pd.DataFrame(probs)
print(df_probs[1].describe())
# Out:
# count    73.000000
# mean     56.168227
# std      37.750347
# min       0.039072
# 25%      17.439158
# 50%      62.378550
# 75%      94.587058
# max      99.719858
# Name: 1, dtype: float64

# %%
for prob in probs:
    print(prob)
# Out:
# [0, 33.72130990028381]
# [1, 49.18190836906433]
# [2, 2.6025187224149704]
# [3, 26.955804228782654]
# [4, 91.00276827812195]
# [5, 97.04357385635376]
# [6, 57.26519823074341]
# [7, 71.80711030960083]
# [8, 7.890298962593079]
# [9, 17.814339697360992]
# [10, 58.60769748687744]
# [11, 81.66725039482117]
# [12, 92.91648864746094]
# [13, 98.60190153121948]
# [14, 5.5894773453474045]
# [15, 99.71985816955566]
# [16, 99.4627058506012]
# [17, 99.61718916893005]
# [18, 98.95826578140259]
# [19, 99.37184453010559]
# [20, 91.67677164077759]
# [21, 0.2770213410258293]
# [22, 63.801223039627075]
# [23, 48.988983035087585]
# [24, 87.17344999313354]
# [25, 20.826230943202972]
# [26, 73.67820739746094]
# [27, 38.62971067428589]
# [28, 28.676515817642212]
# [29, 98.84633421897888]
# [30, 17.152297496795654]
# [31, 13.182057440280914]
# [32, 14.12866860628128]
# [33, 8.019555360078812]
# [34, 0.039072061190381646]
# [35, 2.409599721431732]
# [36, 77.4407148361206]
# [37, 98.91319274902344]
# [38, 1.9169159233570099]
# [39, 17.439158260822296]
# [40, 6.23498372733593]
# [41, 77.71510481834412]
# [42, 45.94154357910156]
# [43, 74.58812594413757]
# [44, 99.33251738548279]
# [45, 99.60830211639404]
# [46, 73.05343747138977]
# [47, 17.9439976811409]
# [48, 97.3365068435669]
# [49, 97.78661727905273]
# [50, 97.22758531570435]
# [51, 96.85643315315247]
# [52, 95.05823850631714]
# [53, 92.65032410621643]
# [54, 94.5870578289032]
# [55, 62.378549575805664]
# [56, 82.42732882499695]
# [57, 17.526771128177643]
# [58, 2.394622750580311]
# [59, 1.2121397070586681]
# [60, 53.36031913757324]
# [61, 98.83236885070801]
# [62, 30.1497220993042]
# [63, 82.96010494232178]
# [64, 10.402188450098038]
# [65, 83.68569016456604]
# [66, 45.101988315582275]
# [67, 94.27286982536316]
# [68, 98.86500239372253]
# [69, 14.990438520908356]
# [70, 0.553766405209899]
# [71, 0.07063652737997472]
# [72, 62.162065505981445]

# %%
# TO DRAW GRAPH : PLOT / HISTOGRAM
fig, axes = plt.subplots(2,2, figsize=(9,4))
plt.suptitle(f"chart_{post_fix}.png",fontsize=20, y=1.01)  # y=gap

df_probs[1].plot(ax=axes[0,0], title="probablity plot", grid=1)
df_probs[1].plot(kind='hist', ax=axes[0,1], title="histogram & boxplot", grid=1)
df_probs[1].plot.bar(ax=axes[1,0], grid=1)
sns.boxplot(df_probs[1], ax=axes[1,1])



# plt.title('My subtitle',fontsize=16)
# plt.savefig(dir_result + f"chart_{post_fix}.png")
# plt.show()
